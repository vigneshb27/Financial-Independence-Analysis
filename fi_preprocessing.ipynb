# %%
import pandas as pd

excel = pd.read_excel('Official FI Survey Raw Data.xlsx')
df = pd.DataFrame(excel)
df
# Out:
# C:\Users\vigen\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#      What is your gender?              Unnamed: 1     How old are you?  \
# 0                Response  Other (please specify)  Open-Ended Response
# 1                    Male                     NaN                   26
# 2                    Male                     NaN                   37
# 3                    Male                     NaN                   20
# 4                    Male                     NaN                   26
# ...                   ...                     ...                  ...
# 1374                 Male                     NaN                   27
# 1375                 Male                     NaN                   29
# 1376                 Male                     NaN                   26
# 1377                 Male                     NaN                   47
# ...

# %%
df['Unnamed: 1'].isna().sum()
# Out:
# 1373

# %%
df['Unnamed: 1'].unique()
# Out:
# array(['Other (please specify)', nan, 'Mayonnaise', 'Meat Popsicle',
#        'No strong feelings', 'Nonbinary Transgender',
#        'Somewhere in between'], dtype=object)

# %%
df.drop(['Unnamed: 1'], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['What is your gender?', 'How old are you?',
#        'How many people contribute to your household income?',
#        'What is your relationship status?  (If more than one applies, pick the option that is closest to the bottom of the list)',
#        'Are your finances combined?',
#        'Do you have, or plan to have, children?',
#        'How many children do you have and intend to have?  (If you have 1 child and want 1 more, enter 2).',
#        'If you have other dependents (not children), how many?',
#        'Are you Financially Independent? (Meaning you do not need to work for money)',
#        'In what year did you achieve FI?',
#        ...
#        'Unnamed: 346',
#        'What are your political leanings on the following topics?  Liberal meaning less funding / less supportive, conservative meaning more funding / supportive. ',
#        'Unnamed: 348', 'Unnamed: 349', 'Unnamed: 350', 'Unnamed: 351',
#        'Unnamed: 352', 'Unnamed: 353', 'Unnamed: 354',
# ...

# %%
df.rename(columns = {'What is your gender?' : 'gender', 'How old are you?' : 'age', 'How many people contribute to your household income?' : 'no_of_people_contribute_income'}, inplace = True)

# %%
df.columns = df.columns.str.replace('\(', '')
df.columns = df.columns.str.replace('\)', '')
df.columns = df.columns.str.replace('\'', '')
df.columns = df.columns.str.replace('What is your relationship status\?', '')
df.columns = df.columns.str.replace('How many children do you have and intend to have\?', '')
df.columns = df.columns.str.replace('If you have 1 child and want 1 more, enter 2.', 'no_of_children')
df.columns = df.columns.str.replace('What are your political leanings on the following topics\?', '')
df.columns = df.columns.str.replace('Liberal meaning less funding / less supportive, conservative meaning more funding / supportive.', 'immigration')
df.columns = df.columns.str.replace('Do you consent to your individual responses being released\?', '')
df.columns = df.columns.str.replace('If you select no, your responses will only be released in aggregate, not as individual data.', '')
df.columns = df.columns.str.replace('IF YOU SELECT YES, you are consenting to your responses being made available on their own.', 'response_release_consent')
df.columns = df.columns.str.replace('If more than one applies, pick the option that is closest to the bottom of the list', 'relationship_status')
df.columns = df.columns.str.replace('total portfolio value across all taxable and nontaxable investment accounts and properties excluding your primary residence\?', '')
df.columns = df.columns.str.replace('What is your', '')
df.columns = df.columns.str.replace('households', 'total_portfolio')
df.columns = df.columns.str.replace('What percentage of your FI number have you attained\?', '')
df.columns = df.columns.str.replace('Enter your answer as a number with no percentage sign. If you are FI, enter 100', '')
df.columns = df.columns.str.replace('e.g. what % FI are you\?', 'curr_percentage_of_fi')

e.g. what % FI are you?

df.columns = [x.strip() for x in df.columns]
df.columns
# Out:
# Object `you` not found.
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\1165211398.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('\(', '')
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\1165211398.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('\)', '')
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\1165211398.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('What is your relationship status\?', '')
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\1165211398.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('How many children do you have and intend to have\?', '')
# ...

# %%
df
# Out:
#         gender                  age no_of_people_contribute_income  \
# 0     Response  Open-Ended Response            Open-Ended Response
# 1         Male                   26                              1
# 2         Male                   37                              2
# 3         Male                   20                              1
# 4         Male                   26                              1
# ...        ...                  ...                            ...
# 1374      Male                   27                              2
# 1375      Male                   29                              1
# 1376      Male                   26                              2
# 1377      Male                   47                              2
# 1378      Male                   31                              1
#
#                      relationship_status Are your finances combined?  \
# 0                               Response                    Response
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'no_of_people_contribute_income',
#        'relationship_status', 'Are your finances combined?',
#        'Do you have, or plan to have, children?', 'no_of_children',
#        'If you have other dependents not children, how many?',
#        'Are you Financially Independent? Meaning you do not need to work for money',
#        'In what year did you achieve FI?',
#        ...
#        'Unnamed: 346', 'immigration', 'Unnamed: 348', 'Unnamed: 349',
#        'Unnamed: 350', 'Unnamed: 351', 'Unnamed: 352', 'Unnamed: 353',
#        'Unnamed: 354', 'response_release_consent'],
#       dtype='object', length=355)

# %%
df.rename(columns = {'Are your finances combined?' : 'combined_finances', 'Do you have, or plan to have, children?' : 'children_status', 'If you have other dependents not children, how many?' : 'no_of_other_dependents', 'Are you Financially Independent? Meaning you do not need to work for money' : 'financially_independent', 'In what year did you achieve FI?' : 'fi_achieved_year', 'Unnamed: 346': 'religiousness_level'}, inplace = True)
df.rename(columns = {'Unnamed: 348' : 'immigration', 'Unnamed: 349' : 'social_services', 'Unnamed: 350' : 'civil_rights', 'Unnamed: 351' : 'religious_freedom', 'Unnamed: 352' : 'military_spending', 'Unnamed: 353' : 'foreign_intervention', 'Unnamed: 354' : 'foreign_aid'}, inplace = True)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'no_of_people_contribute_income',
#        'relationship_status', 'combined_finances', 'children_status',
#        'no_of_children', 'no_of_other_dependents', 'financially_independent',
#        'fi_achieved_year',
#        ...
#        'religiousness_level', 'immigration', 'immigration', 'social_services',
#        'civil_rights', 'religious_freedom', 'military_spending',
#        'foreign_intervention', 'foreign_aid', 'response_release_consent'],
#       dtype='object', length=355)

# %%
df['In what year did you achieve RE?']
# Out:
# 0       Open-Ended Response
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#                ...
# 1374                    NaN
# 1375                    NaN
# 1376                    NaN
# 1377                   2005
# 1378                    NaN
# Name: In what year did you achieve RE?, Length: 1379, dtype: object

# %%
import numpy as np
df.isin([' ','NULL',0, '', np.nan]).mean().head(30)
# Out:
# gender                                                                                                                                                                                                                                                                                             0.000000
# age                                                                                                                                                                                                                                                                                                0.000000
# no_of_people_contribute_income                                                                                                                                                                                                                                                                     0.012328
# ...

# %%
df.isin([' ','NULL',0, np.nan]).mean() < .8
# Out:
# gender                            True
# age                               True
# no_of_people_contribute_income    True
# relationship_status               True
# combined_finances                 True
#                                   ...
# religious_freedom                 True
# military_spending                 True
# foreign_intervention              True
# foreign_aid                       True
# response_release_consent          True
# Length: 355, dtype: bool

# %%
df = df.loc[:, df.isin([' ','NULL',0, np.nan]).mean() < .1]

# %%
df
# Out:
#         gender                  age no_of_people_contribute_income  \
# 0     Response  Open-Ended Response            Open-Ended Response
# 1         Male                   26                              1
# 2         Male                   37                              2
# 3         Male                   20                              1
# 4         Male                   26                              1
# ...        ...                  ...                            ...
# 1374      Male                   27                              2
# 1375      Male                   29                              1
# 1376      Male                   26                              2
# 1377      Male                   47                              2
# 1378      Male                   31                              1
#
#                      relationship_status               children_status  \
# 0                               Response                      Response
# ...

# %%
df.rename(columns = {'Unnamed: 340' : 'logical_thinking', 'Unnamed: 341' : 'creativity', 'Unnamed: 342' : 'drive_for_self_improvement', 'Unnamed: 343' : 'importance_of_relationship', 'Unnamed: 344' : 'internet_consumption', 'Unnamed: 345' : 'introversion'}, inplace = True)
# Out:
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\557705255.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'Unnamed: 340' : 'logical_thinking', 'Unnamed: 341' : 'creativity', 'Unnamed: 342' : 'drive_for_self_improvement', 'Unnamed: 343' : 'importance_of_relationship', 'Unnamed: 344' : 'internet_consumption', 'Unnamed: 345' : 'introversion'}, inplace = True)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'no_of_people_contribute_income',
#        'relationship_status', 'children_status', 'financially_independent',
#        'Which of the following best describes your current or most recent occupation?',
#        'housing situation?', 'Do you have roommates?',
#        'In what country do you live?', 'living environment?',
#        'Using the "cost of living index" the left column of the table at the following link, in what range is the cost of living in your location?  Named cities are examples for the given range, the range is not limited to those cities.  http://www.numbeo.com/cost-of-living/rankings_current.jsp',
#        'How long is your commute, one way?',
#        'highest level of education attained?',
#        'gross household annual wage income including bonuses and commissions?',
#        'total_portfolio',
#        'At what amount in 2016 dollars will you consider yourself:',
#        'Unnamed: 298',
# ...

# %%
df.rename(columns = {'With a ranking of 1 being not at all like you, and 5 being extremely like you, how would you rate your tendencies on the following topics?' : 'frugality', 'Did or do your FIRE goals factor into your choice of:' : 'education', 'Unnamed: 335' : 'job', 'Unnamed: 336' : 'housing_situation', 'Unnamed: 337' : 'location', 'Unnamed: 338' : 'spending_habits'}, inplace = True)
# Out:
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\2729211718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'With a ranking of 1 being not at all like you, and 5 being extremely like you, how would you rate your tendencies on the following topics?' : 'frugality', 'Did or do your FIRE goals factor into your choice of:' : 'education', 'Unnamed: 335' : 'job', 'Unnamed: 336' : 'housing_situation', 'Unnamed: 337' : 'location', 'Unnamed: 338' : 'spending_habits'}, inplace = True)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'no_of_people_contribute_income',
#        'relationship_status', 'children_status', 'financially_independent',
#        'Which of the following best describes your current or most recent occupation?',
#        'housing situation?', 'Do you have roommates?',
#        'In what country do you live?', 'living environment?',
#        'Using the "cost of living index" the left column of the table at the following link, in what range is the cost of living in your location?  Named cities are examples for the given range, the range is not limited to those cities.  http://www.numbeo.com/cost-of-living/rankings_current.jsp',
#        'How long is your commute, one way?',
#        'highest level of education attained?',
#        'gross household annual wage income including bonuses and commissions?',
#        'total_portfolio',
#        'At what amount in 2016 dollars will you consider yourself:',
#        'Unnamed: 298',
# ...

# %%
df.rename(columns = {'At what age did you first learn about FI/RE?' : 'age_when_learnt_about_fi', 'At what age did you first become financially literate?' : 'age_when_financially_literate', 'Did your parents/guardians teach you about money?' : 'did_parent/guardian_teach_about_money', 'What is or was your parents/guardians\' financial status?' : 'financial_status_of_parent/guardian', 'How financially stable was your childhood home?' : 'how_financially_stable_childhood_home', 'Do you plan to move or did you move when FI/RE' : 'do_you_move_when_fi'}, inplace = True)
# Out:
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\2571367983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'At what age did you first learn about FI/RE?' : 'age_when_learnt_about_fi', 'At what age did you first become financially literate?' : 'age_when_financially_literate', 'Did your parents/guardians teach you about money?' : 'did_parent/guardian_teach_about_money', 'What is or was your parents/guardians\' financial status?' : 'financial_status_of_parent/guardian', 'How financially stable was your childhood home?' : 'how_financially_stable_childhood_home', 'Do you plan to move or did you move when FI/RE' : 'do_you_move_when_fi'}, inplace = True)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'no_of_people_contribute_income',
#        'relationship_status', 'children_status', 'financially_independent',
#        'Which of the following best describes your current or most recent occupation?',
#        'housing situation?', 'Do you have roommates?',
#        'In what country do you live?', 'living environment?',
#        'Using the "cost of living index" the left column of the table at the following link, in what range is the cost of living in your location?  Named cities are examples for the given range, the range is not limited to those cities.  http://www.numbeo.com/cost-of-living/rankings_current.jsp',
#        'How long is your commute, one way?',
#        'highest level of education attained?',
#        'gross household annual wage income including bonuses and commissions?',
#        'total_portfolio',
#        'At what amount in 2016 dollars will you consider yourself:',
#        'Unnamed: 298',
# ...

# %%
df.rename(columns = {'How frequently do you check your balances?' : 'frequency_of_checking_balance', '' : 'portfolio_value_excluding_personal_residence', 'What is your gross household annual wage income including bonuses and commissions?' : 'gross_annual_wage', 'What is your highest level of education attained?' : 'highest_lvl_education', 'How long is your commute, one way?' : 'commute', 'In what country do you live?' : 'country', 'What is your living environment?' : 'living_envinronment', 'What is your housing situation?' : 'housing_situation', 'Do you have roommates?' : 'have_roomates', 'Which of the following best describes your current or most recent occupation?' : 'occupation'}, inplace = True)
# Out:
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\158229703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'no_of_people_contribute_income',
#        'relationship_status', 'children_status', 'financially_independent',
#        'occupation', 'housing situation?', 'have_roomates', 'country',
#        'living environment?',
#        'Using the "cost of living index" the left column of the table at the following link, in what range is the cost of living in your location?  Named cities are examples for the given range, the range is not limited to those cities.  http://www.numbeo.com/cost-of-living/rankings_current.jsp',
#        'commute', 'highest level of education attained?',
#        'gross household annual wage income including bonuses and commissions?',
#        'total_portfolio',
#        'At what amount in 2016 dollars will you consider yourself:',
#        'Unnamed: 298',
#        'What percentage of your FI number have you attained?  e.g. what % FI are you? Enter your answer as a number with no percentage sign. If you are FI, enter 100',
# ...

# %%
df.rename(columns = {'At what amount in 2016 dollars will you consider yourself:' : 'amount_for_fi', 'Unnamed: 298' : 'amount_for_re', 'gross household annual wage income including bonuses and commissions?' : 'gross_annual_wage', 'What is or was your parents/guardians financial status?' : 'parent/guardian_financial_status', 'housing situation?' : 'housing situation', 'living environment?' : 'living environment'}, inplace = True)
# Out:
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\2281056401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'At what amount in 2016 dollars will you consider yourself:' : 'amount_for_fi', 'Unnamed: 298' : 'amount_for_re', 'gross household annual wage income including bonuses and commissions?' : 'gross_annual_wage', 'What is or was your parents/guardians financial status?' : 'parent/guardian_financial_status', 'housing situation?' : 'housing situation', 'living environment?' : 'living environment'}, inplace = True)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'no_of_people_contribute_income',
#        'relationship_status', 'children_status', 'financially_independent',
#        'occupation', 'housing situation', 'have_roomates', 'country',
#        'living environment',
#        'Using the "cost of living index" the left column of the table at the following link, in what range is the cost of living in your location?  Named cities are examples for the given range, the range is not limited to those cities.  http://www.numbeo.com/cost-of-living/rankings_current.jsp',
#        'commute', 'highest level of education attained?', 'gross_annual_wage',
#        'total_portfolio', 'amount_for_fi', 'amount_for_re',
#        'curr_percentage_of_fi', 'frequency_of_checking_balance',
#        'do_you_move_when_fi', 'how_financially_stable_childhood_home',
#        'parent/guardian_financial_status',
#        'did_parent/guardian_teach_about_money',
#        'age_when_financially_literate', 'age_when_learnt_about_fi',
# ...

# %%
df.drop(df.columns[11], axis = 1, inplace = True)
df.columns
# Out:
# C:\Users\vigen\AppData\Local\Temp\ipykernel_11412\3952376180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df.columns[11], axis = 1, inplace = True)
# Index(['gender', 'age', 'no_of_people_contribute_income',
#        'relationship_status', 'children_status', 'financially_independent',
#        'occupation', 'housing situation', 'have_roomates', 'country',
#        'living environment', 'commute', 'highest level of education attained?',
#        'gross_annual_wage', 'total_portfolio', 'amount_for_fi',
#        'amount_for_re', 'curr_percentage_of_fi',
#        'frequency_of_checking_balance', 'do_you_move_when_fi',
#        'how_financially_stable_childhood_home',
#        'parent/guardian_financial_status',
#        'did_parent/guardian_teach_about_money',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379 entries, 0 to 1378
# Data columns (total 39 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 1379 non-null   object
#  1   age                                    1379 non-null   object
#  2   no_of_people_contribute_income         1379 non-null   object
#  3   relationship_status                    1379 non-null   object
#  4   children_status                        1377 non-null   object
#  5   financially_independent                1379 non-null   object
#  6   occupation                             1375 non-null   object
#  7   housing situation                      1373 non-null   object
#  8   have_roomates                          1371 non-null   object
#  9   country                                1364 non-null   object
# ...

# %%
df.replace([' ','NULL', ''], np.nan)
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1176 entries, 0 to 1378
# Data columns (total 39 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 1176 non-null   object
#  1   age                                    1176 non-null   object
#  2   no_of_people_contribute_income         1176 non-null   object
#  3   relationship_status                    1176 non-null   object
#  4   children_status                        1176 non-null   object
#  5   financially_independent                1176 non-null   object
#  6   occupation                             1176 non-null   object
#  7   housing situation                      1176 non-null   object
#  8   have_roomates                          1176 non-null   object
#  9   country                                1176 non-null   object
# ...

# %%
df.drop(0, inplace = True)

# %%
df.to_csv('final_fi_data.csv', index=False)
